# %% [markdown]
# <a href="https://colab.research.google.com/github/daniel-h-warwick/warwick-aai-files/blob/main/DataUnderstandingPreparationFeatureEngineering_RZ.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Data Understanding, Data Preparation & Feature Engineering
# ### Module tutor: Dr Ruohan Zhang
#
#
# This practical session is designed to accompany the lectures on:
#
# - **Data Understanding**
# - **Data Preparation**
# - **Feature Engineering**
#
# You will follow a structured workflow that mirrors what we covered in the lecture slides.
#
# # 0️⃣ Introduction
#
# In this workshop, we will:
#
# - Load and inspect a dataset
# - Identify key data quality issues
# - Explore the data visually and statistically
# - Handle missing values
# - Encode categorical variables
# - Scale numerical variables
# - Create new engineered features (BMI)
# - Practice with 5 structured exercises
#
# The goal is to help you build confidence with Python-based data analysis and preparation techniques commonly used in machine learning workflows.
#
# # 1️⃣ Setup

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 2️⃣ Create Example Dataset
#
# We will use a small healthcare dataset to practice core skills. This dataset mirrors the example in the lecture slides (Age, Gender, Height, Weight, SmokingStatus, Disease).

# %%
np.random.seed(26)
n = 40

ages = np.random.randint(20, 80, size=n)
genders = np.random.choice(["Female", "Male"], size=n, p=[0.55, 0.45])
heights = np.random.normal(168, 10, size=n).astype(int)
weights = np.random.normal(70, 15, size=n)

smoking_status = np.random.choice(
    ["Never", "Former", "Current"],
    size=n,
    p=[0.5, 0.25, 0.25]
)

disease = np.random.choice(
    ["Y", "N"],
    size=n,
    p=[0.35, 0.65]
)

df = pd.DataFrame({
    "Age": ages,
    "Gender": genders,
    "Height_cm": heights,
    "Weight_kg": weights,
    "SmokingStatus": smoking_status,
    "Disease": disease
})

# Randomly generate 5 NaN molecules in Weight_kg.
weight_nan_idx = np.random.choice(df.index, 5, replace=False)
df.loc[weight_nan_idx, "Weight_kg"] = np.nan

# Randomly generate 2 NaNs in SmokingStatus
smoke_nan_idx = np.random.choice(df.index, 2, replace=False)
df.loc[smoke_nan_idx, "SmokingStatus"] = np.nan

# Randomly generate 2 NaNs in Disease.
disease_nan_idx = np.random.choice(df.index, 2, replace=False)
df.loc[disease_nan_idx, "Disease"] = np.nan

df
# Out:
#     Age  Gender  Height_cm   Weight_kg SmokingStatus Disease
# 0    73  Female        166   98.989312       Current       Y
# 1    26    Male        166   72.073097         Never       N
# 2    68  Female        172   73.103718         Never       Y
# 3    21    Male        169   73.818070       Current       N
# 4    58    Male        147  100.388970       Current       Y
# 5    39    Male        171   48.798126       Current       N
# 6    33  Female        170   74.108334        Former       N
# 7    46    Male        168         NaN         Never       N
# 8    52    Male        153   87.519539         Never       Y
# 9    24    Male        181   98.791877         Never       Y
# 10   54    Male        154   65.306190       Current       N
# 11   65    Male        159   72.142941         Never       N
# 12   37    Male        178   59.774524         Never       N
# 13   75  Female        154  112.249668         Never       N
# 14   71    Male        150   71.405272         Never       Y
# 15   73  Female        166         NaN         Never       N
# 16   45  Female        166   45.728603         Never       N
# 17   72    Male        174   62.749048       Current       Y
# 18   66  Female        174   58.319635        Former       N
# 19   44    Male        163   69.802603         Never       N
# 20   41    Male        186         NaN         Never       N
# 21   50  Female        164   65.886702         Never     NaN
# 22   35  Female        184   67.460049       Current       Y
# 23   62    Male        164         NaN         Never       N
# 24   66    Male        176   77.860551        Former       Y
# 25   43    Male        152   61.928539         Never       N
# 26   58  Female        173   66.654943       Current       Y
# 27   67    Male        170         NaN         Never     NaN
# 28   47    Male        163   48.633974           NaN       N
# 29   76  Female        165   75.169515         Never       N
# 30   38  Female        170   61.819984        Former       N
# 31   67  Female        180   57.135626        Former       N
# 32   73    Male        160   69.958200        Former       Y
# 33   32    Male        177   90.758927         Never       Y
# 34   67    Male        163   68.883208       Current       Y
# 35   36  Female        165   55.448018         Never       Y
# 36   78  Female        162   86.141928           NaN       N
# 37   32  Female        160   45.406862         Never       N
# 38   70  Female        155   97.485669       Current       N
# 39   32  Female        174   58.118204         Never       N

# %%
df.isna().sum()
# Out:
# Age              0
# Gender           0
# Height_cm        0
# Weight_kg        5
# SmokingStatus    2
# Disease          2
# dtype: int64

# %% [markdown]
# # 3️⃣ Data Understanding
#
# This step answers: “What is in the dataset?”
# Before preparing the data, we should understand it.
#
# ## 3.1 First Look at the Data

# %%
df.head()
# Out:
#    Age  Gender  Height_cm   Weight_kg SmokingStatus Disease
# 0   73  Female        166   98.989312       Current       Y
# 1   26    Male        166   72.073097         Never       N
# 2   68  Female        172   73.103718         Never       Y
# 3   21    Male        169   73.818070       Current       N
# 4   58    Male        147  100.388970       Current       Y

# %% [markdown]
# Explanation
#
# * Displays the first 5 rows
# * Confirms that data loaded correctly
# * Helps us spot obvious issues

# %% [markdown]
# ## 3.2 Shape, Data Types, Missing Values

# %%
print("Shape:", df.shape)
print("\nData Types:\n", df.dtypes)
print("\nMissing Values per Column:\n", df.isna().sum())
# Out:
# Shape: (40, 6)
#
# Data Types:
#  Age                int64
# Gender            object
# Height_cm          int64
# Weight_kg        float64
# SmokingStatus     object
# Disease           object
# dtype: object
#
# Missing Values per Column:
#  Age              0
# Gender           0
# Height_cm        0
# Weight_kg        5
# SmokingStatus    2
# Disease          2
# dtype: int64

# %% [markdown]
# Explanation
#
# * shape tells us rows and columns
# * dtypes shows numeric vs categorical types
# * isna().sum() helps locate missing values

# %% [markdown]
# ## 3.3 Summary Statistics

# %%
df.describe(include="all")
# Out:
#               Age Gender   Height_cm   Weight_kg SmokingStatus Disease
# count   40.000000     40   40.000000   35.000000            38      38
# unique        NaN      2         NaN         NaN             3       2
# top           NaN   Male         NaN         NaN         Never       N
# freq          NaN     22         NaN         NaN            22      24
# mean    52.800000    NaN  166.600000   71.423441           NaN     NaN
# std     17.043233    NaN    9.369344   16.541574           NaN     NaN
# min     21.000000    NaN  147.000000   45.406862           NaN     NaN
# 25%     37.750000    NaN  161.500000   60.797254           NaN     NaN
# 50%     53.000000    NaN  166.000000   69.802603           NaN     NaN
# 75%     67.250000    NaN  173.250000   76.515033           NaN     NaN
# max     78.000000    NaN  186.000000  112.249668           NaN     NaN

# %% [markdown]
# This summary shows:
# * Numerical statistics: Mean, median, std dev, minimum and maximum
# * Categorical summaries: Count of each category, and number of unique values
#
# This helps us understand the dataset's distribution and identify inconsistencies.
#
# **BUT unfortunately, there are Nans in this dataset. We will fix it later.**

# %% [markdown]
# ## 3.4 Check for Duplicate Rows

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# **Why This Matters**
#
# Duplicate rows can:
#
# * Bias the analysis
# * Inflate model performance
# * Misrepresent real-world distributions

# %% [markdown]
# ## 3.5 Visualizing the Data
# Histogram of Age

# %%
df["Age"].hist()
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# Boxplot of Weight

# %%
sns.boxplot(x=df["Weight_kg"])
plt.title("Weight Distribution")
plt.show()

# %% [markdown]
# Bar Chart of Smoking Status

# %%
df["SmokingStatus"].value_counts().plot(kind="bar")
plt.title("Smoking Status Frequency")
plt.xlabel("Category")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# Visual checks help reveal:
#
# * Skewed features
# * Outliers
# * Imbalanced categories

# %% [markdown]
# # 4️⃣ Data Preparation
#
# Once we understand the data, we clean and prepare it for modelling.
#
# ## 4.1 Handling Missing Values

# %% [markdown]
# **Option 1: Remove Rows with Missing Values (Only if missing is small)**
#
# When to use:
# * The missing proportion is small (e.g., < 5–10%)
# * The rows do not contain important information
# * Dataset is large
#
# When not to use:
# * Small datasets
# * Important variables have missing values
# * Missingness is systematic

# %%
df.isna().sum()

df_clean = df.dropna()
print(df_clean)

print("Original shape:", df.shape)
print("After dropna:", df_clean.shape)
# Out:
#     Age  Gender  Height_cm   Weight_kg SmokingStatus Disease
# 0    73  Female        166   98.989312       Current       Y
# 1    26    Male        166   72.073097         Never       N
# 2    68  Female        172   73.103718         Never       Y
# 3    21    Male        169   73.818070       Current       N
# 4    58    Male        147  100.388970       Current       Y
# 5    39    Male        171   48.798126       Current       N
# 6    33  Female        170   74.108334        Former       N
# 8    52    Male        153   87.519539         Never       Y
# 9    24    Male        181   98.791877         Never       Y
# 10   54    Male        154   65.306190       Current       N
# 11   65    Male        159   72.142941         Never       N
# 12   37    Male        178   59.774524         Never       N
# 13   75  Female        154  112.249668         Never       N
# 14   71    Male        150   71.405272         Never       Y
# 16   45  Female        166   45.728603         Never       N
# 17   72    Male        174   62.749048       Current       Y
# 18   66  Female        174   58.319635        Former       N
# 19   44    Male        163   69.802603         Never       N
# 22   35  Female        184   67.460049       Current       Y
# 24   66    Male        176   77.860551        Former       Y
# 25   43    Male        152   61.928539         Never       N
# 26   58  Female        173   66.654943       Current       Y
# 29   76  Female        165   75.169515         Never       N
# 30   38  Female        170   61.819984        Former       N
# 31   67  Female        180   57.135626        Former       N
# 32   73    Male        160   69.958200        Former       Y
# 33   32    Male        177   90.758927         Never       Y
# 34   67    Male        163   68.883208       Current       Y
# 35   36  Female        165   55.448018         Never       Y
# 37   32  Female        160   45.406862         Never       N
# 38   70  Female        155   97.485669       Current       N
# 39   32  Female        174   58.118204         Never       N
# Original shape: (40, 6)
# After dropna: (32, 6)

# %% [markdown]
# **Option 2: Impute Missing Values (Recommended)**
# Instead of dropping missing rows, we can fill them in using various strategies:
#
# Numerical columns → mean or median
#
# Categorical columns → mode (most frequent category)

# %%
# Step 1: Identify numeric and categorical columns
num_cols = df_clean.select_dtypes(include=["int64", "float64"]).columns
cat_cols = df_clean.select_dtypes(include=["object"]).columns

# Step 2: Impute numeric columns using mean
df_clean[num_cols] = df_clean[num_cols].fillna(df_clean[num_cols].mean())

# Step 3: Impute categorical columns using mode
df_clean[cat_cols] = df_clean[cat_cols].fillna(df_clean[cat_cols].mode().iloc[0])

# Step 4: Check if missing values remain
df_clean.isna().sum()

print("Current shape:", df.shape)
# Out:
# Current shape: (40, 6)
# /tmp/ipython-input-1396664255.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean[num_cols] = df_clean[num_cols].fillna(df_clean[num_cols].mean())
# /tmp/ipython-input-1396664255.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean[cat_cols] = df_clean[cat_cols].fillna(df_clean[cat_cols].mode().iloc[0])

# %% [markdown]
# # 4.2 Encoding Categorical Variables
#
# Machine learning models require numerical input.
# We convert categorical variables using:
#
# * Label Encoding for binary categories
# * One-Hot Encoding for multi-category variables

# %%
# Label encoding for Disease
df_clean.loc[:, "Disease"] = df_clean["Disease"].map({"Y": 1, "N": 0})

# One-hot encoding for Gender and SmokingStatus
df_encoded = pd.get_dummies(
    df_clean,
    columns=["Gender", "SmokingStatus"],
    drop_first=True
)

df_encoded.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-146044469.py in <cell line: 0>()
#       1 # Label encoding for Disease
# ----> 2 df_clean.loc[:, "Disease"] = df_clean["Disease"].map({"Y": 1, "N": 0})
#       3
#       4 # One-hot encoding for Gender and SmokingStatus
#       5 df_encoded = pd.get_dummies(
#
# NameError: name 'df_clean' is not defined

# %% [markdown]
# # 4.3 Feature Scaling
#
# Scaling improves model performance, especially for methods like:
# * Logistic Regression
# * K-Means
# * PCA
#
# We use StandardScaler.

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
df_scaled = df_encoded.copy()
df_scaled[num_cols] = scaler.fit_transform(df_scaled[num_cols])

df_scaled.head()
# Out:
#         Age  Height_cm  Weight_kg Disease  Gender_Male  SmokingStatus_Former  \
# 0  1.233744  -0.029133   1.662267       1        False                 False
# 1 -1.463278  -0.029133   0.013745       0         True                 False
# 2  0.946827   0.592363   0.076866       1        False                 False
# 3 -1.750195   0.281615   0.120618       0         True                 False
# 4  0.372992  -1.997203   1.747991       1         True                 False
#
#    SmokingStatus_Never
# 0                False
# 1                 True
# 2                 True
# 3                False
# 4                False

# %% [markdown]
# # 5️⃣ Feature Engineering
#
# Feature engineering improves the quality and predictive power of data.
#
# ## 5.1 Feature Creation (Example: BMI)

# %%
df_clean["BMI"] = df_clean["Weight_kg"] / (df_clean["Height_cm"]/100)**2
df_clean[["Height_cm", "Weight_kg", "BMI"]]
# Out:
# /tmp/ipython-input-4289272459.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean["BMI"] = df_clean["Weight_kg"] / (df_clean["Height_cm"]/100)**2
#     Height_cm   Weight_kg        BMI
# 0         166   98.989312  35.922961
# 1         166   72.073097  26.155138
# 2         172   73.103718  24.710559
# 3         169   73.818070  25.845758
# 4         147  100.388970  46.457018
# 5         171   48.798126  16.688255
# 6         170   74.108334  25.643022
# 8         153   87.519539  37.387133
# 9         181   98.791877  30.155330
# 10        154   65.306190  27.536764
# 11        159   72.142941  28.536427
# 12        178   59.774524  18.865839
# 13        154  112.249668  47.330776
# 14        150   71.405272  31.735676
# 16        166   45.728603  16.594790
# 17        174   62.749048  20.725673
# 18        174   58.319635  19.262662
# 19        163   69.802603  26.272198
# 22        184   67.460049  19.925582
# 24        176   77.860551  25.135767
# 25        152   61.928539  26.804250
# 26        173   66.654943  22.271023
# 29        165   75.169515  27.610474
# 30        170   61.819984  21.390998
# 31        180   57.135626  17.634453
# 32        160   69.958200  27.327422
# 33        177   90.758927  28.969621
# 34        163   68.883208  25.926158
# 35        165   55.448018  20.366582
# 37        160   45.406862  17.737055
# 38        155   97.485669  40.576761
# 39        174   58.118204  19.196130

# %% [markdown]
# **Why BMI?**
#
# BMI combines height and weight into a more meaningful health indicator than either alone.

# %% [markdown]
# ## 5.2 Simple Feature Selection
#
# We can examine correlations:

# %%
df_clean.corr(numeric_only=True)["BMI"].sort_values(ascending=False)
# Out:
# BMI          1.000000
# Weight_kg    0.906175
# Age          0.364965
# Height_cm   -0.630443
# Name: BMI, dtype: float64

# %% [markdown]
# Features with high absolute correlations may be:
#
# * Important predictors
# * Candidates for deeper analysis
#
# Features with low correlation may be removed to reduce noise.
#
# We will look into these points in the following sessions.

# %% [markdown]
# # 6️⃣ Exercises
# You now have 3 exercises at ascending difficulty levels.
#
# **Exercise 1： Online Retail Orders (Beginner Level)**
#
# **Task Description**
#
# You are given a small dataset of online retail orders. It includes customer age, order amount, number of items, and membership status. Some values are missing.
#
# Your tasks:
# * Generate the dataset below.
# * Check for missing values.
# * Remove rows that contain any missing values.
#
# Calculate:
# * Average order amount
# * Largest and smallest order
# * Find which membership category (“Basic”, “Silver”, “Gold”) has the highest average order amount.

# %%
# dataset
np.random.seed(100)

df1 = pd.DataFrame({
    "CustomerAge": np.random.randint(18, 70, 12),
    "Membership": np.random.choice(["Basic", "Silver", "Gold"], 12),
    "OrderAmount": np.random.normal(120, 40, 12),
    "ItemsPurchased": np.random.randint(1, 6, 12)
})

# introduce missing values
df1.loc[np.random.choice(df1.index, 2, replace=False), "OrderAmount"] = np.nan
df1.loc[np.random.choice(df1.index, 1, replace=False), "ItemsPurchased"] = np.nan

df1
# Out:
#     CustomerAge Membership  OrderAmount  ItemsPurchased
# 0            26       Gold   130.640654             4.0
# 1            42       Gold   115.448213             3.0
# 2            21     Silver   160.442646             4.0
# 3            57      Basic    62.369153             1.0
# 4            41      Basic   159.222766             2.0
# 5            33      Basic   175.079852             NaN
# 6            66      Basic          NaN             5.0
# 7            28       Gold   139.236965             3.0
# 8            48      Basic    69.323577             1.0
# 9            52     Silver   130.840204             1.0
# 10           20     Silver          NaN             3.0
# 11           52       Gold   139.014762             3.0

# %%
# ============================ Please write your answer below ============================
print("\nMissing Values per Column:\n", df1.isna().sum())

df1_clean = df1.dropna()

print("Original shape:", df1.shape)
print("After drop:", df1_clean.shape)

avg_order_amt = df1_clean.loc[:,"OrderAmount"].mean()
print("Order amount average: ", avg_order_amt)

membership_averages = df1_clean.groupby("Membership")["OrderAmount"].mean()
print("Membership Order Amount Averages:", membership_averages)

max_avg_cat = membership_averages.idxmax()
max_avg_val = membership_averages[max_avg_cat]
print(f"Max average category: {max_avg_cat}, value: {max_avg_val}")
# Out:
# Missing Values per Column:
#  CustomerAge       0
# Membership        0
# OrderAmount       2
# ItemsPurchased    1
# dtype: int64
# Original shape: (12, 4)
# After drop: (9, 4)
# Order amount average:  122.94877089682558
# Membership Order Amount Averages: Membership
# Basic      96.971832
# Gold      131.085148
# Silver    145.641425
# Name: OrderAmount, dtype: float64
# Max average category: Silver, value: 145.64142468801643

# %% [markdown]
# **Exercise 2： Ride-Sharing Trips (Intermediate Level)**
#
# **Task Description**
#
# A ride-sharing platform collected data on user trips. The dataset includes distance, duration, pickup time, rider type, and fare. Some values are missing.
#
# **Your tasks:**
#
# 1. Count missing values in each column.
#
# 2. Impute:
# * Missing Fare using median
# * Missing RiderType using most frequent
#
# 3. Create two new features:
# * Speed_kmh = (Distance_km / Duration_min) * 60
# * IsPeakHour: 1 if PickupHour is between 7–9 or 17–19, else 0
#
# 4. Calculate average speed by RiderType and PeakHour.
#
# 5. Identify which RiderType travels fastest during peak hours.

# %%
# dataset
np.random.seed(200)

df2 = pd.DataFrame({
    "Distance_km": np.random.uniform(1, 25, 40),
    "Duration_min": np.random.uniform(5, 60, 40),
    "PickupHour": np.random.randint(0, 24, 40),
    "RiderType": np.random.choice(["Economy", "Premium", "Pool"], 40),
    "Fare": np.random.uniform(5, 60, 40)
})

# introduce missing values
df2.loc[np.random.choice(df2.index, 5, replace=False), "Fare"] = np.nan
df2.loc[np.random.choice(df2.index, 3, replace=False), "RiderType"] = np.nan

df2
# Out:
#     Distance_km  Duration_min  PickupHour RiderType       Fare
# 0     23.743174     15.322903          16      Pool  35.729405
# 1      6.437138     28.047633           5       NaN  32.060112
# 2     15.266083     41.629940           4      Pool  38.006941
# 3     11.279408     33.457649          10   Premium  55.636025
# 4     19.339376     51.997089          22   Premium        NaN
# 5      1.068654     14.405622           6   Premium  37.421511
# 6      9.578168     58.798718           9   Premium  39.992162
# 7     22.832677     21.569505           6   Economy  59.241386
# 8     11.945944     17.784700          14   Economy  44.348967
# 9     24.563265     48.541503           7      Pool  28.822581
# 10    21.816568     53.618339           0      Pool  46.927924
# 11    24.664660     59.301419          18   Economy  55.880109
# 12    23.158401      5.883499          18   Premium  32.387407
# 13     8.288640     16.247492          11       NaN  54.352815
# 14    21.306484     40.505738          16      Pool  38.898086
# 15     3.909327     33.086961           8   Premium  27.400839
# 16    19.853831     16.568081          19   Economy  44.714440
# 17     7.012121     21.991374          20       NaN        NaN
# 18     3.304713      5.968398           8   Premium  45.257263
# 19    23.643785     40.468705          17   Economy  45.689361
# 20    20.825204     34.076666          12   Premium  52.070433
# 21    13.439803     38.625482          15      Pool  53.056215
# 22    21.964010     21.451902           1   Economy  47.013199
# 23    14.881017     53.940961           0   Premium  15.724173
# 24    11.802028     44.579598           2      Pool   9.077696
# 25    17.323768     57.410140           3   Economy  38.477360
# 26    11.066215     26.840887           4      Pool   5.717442
# 27    16.369443     59.375629           7   Economy  27.511796
# 28    15.607751     29.886867          12      Pool        NaN
# 29     3.530419     45.044010          13   Economy  18.901298
# 30    24.185070     23.926952          17      Pool  21.547877
# 31    19.208810     55.388581          13   Economy  35.854109
# 32    17.311404      8.542902          20   Economy  55.239867
# 33     8.904354      5.511177           8   Economy  23.471623
# 34     1.634917     31.249445          20      Pool  43.167689
# 35    20.287849     30.864290           6   Economy   6.415288
# 36    24.347901      6.740103           3      Pool        NaN
# 37     7.790515     55.220387           3   Economy  59.876335
# 38    16.577792     56.164511          16   Economy  40.324023
# 39     7.373802     33.286663          20      Pool        NaN

# %%
# ============================ Please write your answer below ============================


df2_clean = df2.copy()
print("BEFORE")
print("Current shape:", df2_clean.shape)
print("Missing Values per Column:\n", df2_clean.isna().sum())

fare_lbl = "Fare"
rider_type_lbl = "RiderType"

# Impute fare column using median
df2_clean[fare_lbl] = df2_clean[fare_lbl].fillna(df2_clean[fare_lbl].median())

# Impute rider type column using most frequent
df2_clean[rider_type_lbl] = df2_clean[rider_type_lbl].fillna(df2_clean[rider_type_lbl].mode().iloc[0])

print("\nAFTER")
print("Current shape:", df2_clean.shape)
print("Missing Values per Column:\n", df2_clean.isna().sum())

# Speed_kmh = (Distance_km / Duration_min) * 60
# IsPeakHour: 1 if PickupHour is between 7–9 or 17–19, else 0
df2_clean["Speed_kmh"] = df2_clean['Distance_km'] / df2_clean['Duration_min'] * 60
df2_clean["IsPeakHour"] = np.where(
    ((df2_clean['PickupHour'] >= 7) & (df2_clean['PickupHour'] <= 9)) |
    ((df2_clean['PickupHour'] >= 17) & (df2_clean['PickupHour'] <= 19)),
    1, # true
    0) # false

# Calculate average speed by RiderType and PeakHour.
avg_speeds = df2_clean.groupby(["RiderType","IsPeakHour"])["Speed_kmh"].mean()
print("\nAverage speeds by rider type and peak hour\n", avg_speeds)

# Identify which RiderType travels fastest during peak hours.
avg_speeds_df = avg_speeds.reset_index()
peak_data = avg_speeds_df[avg_speeds_df["IsPeakHour"] == 1]
fastest_row_index = peak_data["Speed_kmh"].idxmax()
fastest_rider = peak_data.loc[fastest_row_index, "RiderType"]
fastest_speed = peak_data.loc[fastest_row_index, "Speed_kmh"]

print(f"\nPeak hours fastest rider: {fastest_rider} at {fastest_speed:.2f} km/h")

#df2_clean
# Out:
# BEFORE
# Current shape: (40, 5)
# Missing Values per Column:
#  Distance_km     0
# Duration_min    0
# PickupHour      0
# RiderType       3
# Fare            5
# dtype: int64
#
# AFTER
# Current shape: (40, 5)
# Missing Values per Column:
#  Distance_km     0
# Duration_min    0
# PickupHour      0
# RiderType       0
# Fare            0
# dtype: int64
#
# Average speeds by rider type and peak hour
#  RiderType  IsPeakHour
# Economy    0             35.351802
#            1             49.078441
# Pool       0             45.177677
#            1             45.504415
# Premium    0             20.042927
#            1             71.563711
# Name: Speed_kmh, dtype: float64
#
# Peak hours fastest rider: Premium at 71.56 km/h

# %% [markdown]
# **Exercise 3： Movie Ratings Analytics (Advanced Level)**
#
# **Task Description**
#
# A streaming platform wants to analyse movie ratings. You are given a synthetic dataset containing movie duration, release year, rating, viewer age, and genre.
#
# **Your tasks:**
# 1. Add missing value indicator columns:
#
# * Rating_missing
#
# * Age_missing
#
# 2. Impute:
#
# * Missing Rating using median
#
# * Missing ViewerAge using median
#
# 3. Create new features:
#
# * AgeGroup using pd.cut()
#
# * IsOldMovie = 1 if Year < 2000
#
# 4. Compute correlation matrix for numerical features.
#
# 5. Identify the top 2 strongest predictors of Rating.
#
# 6. Interpret whether Duration is positively or negatively correlated with Rating based on output.

# %%
# dataset
np.random.seed(300)

df3 = pd.DataFrame({
    "Duration_min": np.random.randint(70, 180, 50),
    "ReleaseYear": np.random.randint(1980, 2023, 50),
    "Rating": np.random.uniform(1, 10, 50),
    "ViewerAge": np.random.randint(12, 70, 50),
    "Genre": np.random.choice(["Drama", "Comedy", "Action", "Sci-Fi"], 50)
})

# introduce missing values
df3.loc[np.random.choice(df3.index, 6, replace=False), "Rating"] = np.nan
df3.loc[np.random.choice(df3.index, 4, replace=False), "ViewerAge"] = np.nan

df3
# Out:
#     Duration_min  ReleaseYear    Rating  ViewerAge   Genre
# 0            151         2011  8.672795       15.0  Comedy
# 1            167         2014  3.208460       46.0  Sci-Fi
# 2             91         1986  9.615304       36.0  Action
# 3            144         1982  8.825262        NaN  Action
# 4            176         1990  2.186563       61.0  Sci-Fi
# 5             79         2013  5.717687       69.0  Action
# 6            155         1993  7.551714       69.0  Comedy
# 7            161         2006  3.893026        NaN  Sci-Fi
# 8            173         2017  8.743593       45.0   Drama
# 9             92         2004       NaN       60.0  Comedy
# 10           111         2001  5.918329       61.0  Comedy
# 11           146         2001  5.464716       24.0   Drama
# 12           164         2005  9.431687       60.0  Action
# 13           130         1985  1.585998       23.0  Comedy
# 14            73         2011       NaN       19.0  Sci-Fi
# 15           164         2010  4.875512       41.0  Sci-Fi
# 16           121         2016  8.565186       65.0   Drama
# 17           169         1980  7.884329       33.0  Sci-Fi
# 18           154         2010  3.487485       62.0   Drama
# 19           134         2020       NaN       13.0  Action
# 20           168         2005  6.830574       26.0  Comedy
# 21           171         2004  2.762680       47.0  Action
# 22            89         2015  6.484351       39.0  Sci-Fi
# 23           178         2013  8.160473       56.0  Sci-Fi
# 24           119         2001  2.301073       64.0  Comedy
# 25           175         2022  2.631790       32.0  Comedy
# 26           143         1981  8.745225       40.0  Comedy
# 27           141         1984       NaN       17.0  Comedy
# 28           117         1992  6.589472       29.0   Drama
# 29           154         1995  5.366266       20.0  Sci-Fi
# 30           127         1996  4.856390       23.0  Action
# 31            73         1982  6.277880       33.0   Drama
# 32           144         2008  3.567401       62.0  Comedy
# 33           177         2021  7.883965       31.0  Action
# 34            86         2015  1.668515        NaN   Drama
# 35           129         1985       NaN       24.0  Action
# 36           147         2011  4.407826       58.0  Sci-Fi
# 37           114         2012       NaN        NaN  Sci-Fi
# 38           106         2022  4.485158       31.0   Drama
# 39           130         2004  2.955717       12.0  Comedy
# 40            94         2006  3.728331       69.0  Sci-Fi
# 41           163         1995  7.473579       13.0   Drama
# 42           159         1988  5.340825       54.0  Action
# 43            98         2000  2.200508       42.0   Drama
# 44           149         1984  9.692671       56.0  Comedy
# 45           161         2021  9.021369       13.0   Drama
# 46            83         2002  3.923391       17.0  Comedy
# 47           125         1989  8.682630       61.0  Comedy
# 48            93         2015  8.984383       18.0  Comedy
# 49           125         2018  6.579136       31.0  Sci-Fi

# %%
# ============================ Please write your answer below ============================

df3_mod = df3.copy()

# Add missing value indicator columns: Rating_missing, Age_missing
df3_mod["Rating_missing"] = np.where(df3['Rating'].isna(), 1, 0)
df3_mod["Age_missing"] = np.where(df3['ViewerAge'].isna(), 1, 0)

# Impute: Missing Rating using median, Missing ViewerAge using median
df3_mod['Rating'] = df3_mod['Rating'].fillna(df3['Rating'].median())
df3_mod['ViewerAge'] = df3_mod['ViewerAge'].fillna(df3['ViewerAge'].median())

# Create new features:
#   AgeGroup using pd.cut()
#   IsOldMovie = 1 if Year < 2000

age_bins = [0, 18, 35, 50, 100]
age_labels = ["0-18", "19-35", "36-50", "51+"]

df3_mod["AgeGroup"] = pd.cut(df3_mod["ViewerAge"], bins=age_bins, labels=age_labels)
df3_mod["IsOldMovie"] = np.where(df3_mod['ReleaseYear'] < 2000,
                                1,
                                0)

# Compute correlation matrix for numerical features.

# Identify the top 2 strongest predictors of Rating.

# Interpret whether Duration is positively or negatively correlated with Rating based on output.

df3_mod
# Out:
#     Duration_min  ReleaseYear    Rating  ViewerAge   Genre  Rating_missing  \
# 0            151         2011  8.672795       15.0  Comedy               0
# 1            167         2014  3.208460       46.0  Sci-Fi               0
# 2             91         1986  9.615304       36.0  Action               0
# 3            144         1982  8.825262       37.5  Action               0
# 4            176         1990  2.186563       61.0  Sci-Fi               0
# 5             79         2013  5.717687       69.0  Action               0
# 6            155         1993  7.551714       69.0  Comedy               0
# 7            161         2006  3.893026       37.5  Sci-Fi               0
# 8            173         2017  8.743593       45.0   Drama               0
# 9             92         2004  5.818008       60.0  Comedy               1
# 10           111         2001  5.918329       61.0  Comedy               0
# 11           146         2001  5.464716       24.0   Drama               0
# 12           164         2005  9.431687       60.0  Action               0
# 13           130         1985  1.585998       23.0  Comedy               0
# 14            73         2011  5.818008       19.0  Sci-Fi               1
# 15           164         2010  4.875512       41.0  Sci-Fi               0
# 16           121         2016  8.565186       65.0   Drama               0
# 17           169         1980  7.884329       33.0  Sci-Fi               0
# 18           154         2010  3.487485       62.0   Drama               0
# 19           134         2020  5.818008       13.0  Action               1
# 20           168         2005  6.830574       26.0  Comedy               0
# 21           171         2004  2.762680       47.0  Action               0
# 22            89         2015  6.484351       39.0  Sci-Fi               0
# 23           178         2013  8.160473       56.0  Sci-Fi               0
# 24           119         2001  2.301073       64.0  Comedy               0
# 25           175         2022  2.631790       32.0  Comedy               0
# 26           143         1981  8.745225       40.0  Comedy               0
# 27           141         1984  5.818008       17.0  Comedy               1
# 28           117         1992  6.589472       29.0   Drama               0
# 29           154         1995  5.366266       20.0  Sci-Fi               0
# 30           127         1996  4.856390       23.0  Action               0
# 31            73         1982  6.277880       33.0   Drama               0
# 32           144         2008  3.567401       62.0  Comedy               0
# 33           177         2021  7.883965       31.0  Action               0
# 34            86         2015  1.668515       37.5   Drama               0
# 35           129         1985  5.818008       24.0  Action               1
# 36           147         2011  4.407826       58.0  Sci-Fi               0
# 37           114         2012  5.818008       37.5  Sci-Fi               1
# 38           106         2022  4.485158       31.0   Drama               0
# 39           130         2004  2.955717       12.0  Comedy               0
# 40            94         2006  3.728331       69.0  Sci-Fi               0
# 41           163         1995  7.473579       13.0   Drama               0
# 42           159         1988  5.340825       54.0  Action               0
# 43            98         2000  2.200508       42.0   Drama               0
# 44           149         1984  9.692671       56.0  Comedy               0
# 45           161         2021  9.021369       13.0   Drama               0
# 46            83         2002  3.923391       17.0  Comedy               0
# 47           125         1989  8.682630       61.0  Comedy               0
# 48            93         2015  8.984383       18.0  Comedy               0
# 49           125         2018  6.579136       31.0  Sci-Fi               0
#
#     Age_missing AgeGroup  IsOldMovie
# 0             0     0-18           0
# 1             0    36-50           0
# 2             0    36-50           1
# 3             1    36-50           1
# 4             0      51+           1
# 5             0      51+           0
# 6             0      51+           1
# 7             1    36-50           0
# 8             0    36-50           0
# 9             0      51+           0
# 10            0      51+           0
# 11            0    19-35           0
# 12            0      51+           0
# 13            0    19-35           1
# 14            0    19-35           0
# 15            0    36-50           0
# 16            0      51+           0
# 17            0    19-35           1
# 18            0      51+           0
# 19            0     0-18           0
# 20            0    19-35           0
# 21            0    36-50           0
# 22            0    36-50           0
# 23            0      51+           0
# 24            0      51+           0
# 25            0    19-35           0
# 26            0    36-50           1
# 27            0     0-18           1
# 28            0    19-35           1
# 29            0    19-35           1
# 30            0    19-35           1
# 31            0    19-35           1
# 32            0      51+           0
# 33            0    19-35           0
# 34            1    36-50           0
# 35            0    19-35           1
# 36            0      51+           0
# 37            1    36-50           0
# 38            0    19-35           0
# 39            0     0-18           0
# 40            0      51+           0
# 41            0     0-18           1
# 42            0      51+           1
# 43            0    36-50           0
# 44            0      51+           1
# 45            0     0-18           0
# 46            0     0-18           0
# 47            0      51+           1
# 48            0     0-18           0
# 49            0    19-35           0
